# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ellah\OneDrive\Data Science Projects\asthma-weather-impact\asthma-ed-visit-rates_2019.csv")

# %%
df.head()
# Out:
#      LGHC Indicator Name   Geography  Year    Age Group            Strata  \
# 0  Asthma ED Visit Rates     Alameda  2015  18 and Over  Total Population
# 1  Asthma ED Visit Rates      Amador  2015  18 and Over  Total Population
# 2  Asthma ED Visit Rates       Butte  2015  18 and Over  Total Population
# 3  Asthma ED Visit Rates   Calaveras  2015  18 and Over  Total Population
# 4  Asthma ED Visit Rates  California  2015  18 and Over  Total Population
#
#    Strata Name Numerator  Rate  LGHC Indicator ID  LGHC Target Rate
# 0  18 and Over     6,513  53.1                  7                28
# 1  18 and Over       151  49.1                  7                28
# 2  18 and Over       736  43.8                  7                28
# 3  18 and Over       139  42.7                  7                28
# 4  18 and Over   117,854  40.0                  7                28

# %% [markdown]
# LGHC Indicator Name and LGHC Indicator ID are both the same information so I am dropping the ID column.

# %%
df = df.drop(columns=['LGHC Indicator ID', 'Strata'])

df = df[~df['Age Group'].isin([
    'Under 20',
    'Under 19'
])]

# %%
df.head()
# Out:
#      LGHC Indicator Name   Geography  Year    Age Group  Strata Name  \
# 0  Asthma ED Visit Rates     Alameda  2015  18 and Over  18 and Over
# 1  Asthma ED Visit Rates      Amador  2015  18 and Over  18 and Over
# 2  Asthma ED Visit Rates       Butte  2015  18 and Over  18 and Over
# 3  Asthma ED Visit Rates   Calaveras  2015  18 and Over  18 and Over
# 4  Asthma ED Visit Rates  California  2015  18 and Over  18 and Over
#
#   Numerator  Rate  LGHC Target Rate
# 0     6,513  53.1                28
# 1       151  49.1                28
# 2       736  43.8                28
# 3       139  42.7                28
# 4   117,854  40.0                28
